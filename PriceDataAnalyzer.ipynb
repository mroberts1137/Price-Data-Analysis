# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd

# %%
def SMA(x, l):
    x_len = len(x)
    x = np.pad(x, (l, 0), 'edge')
    window = np.zeros(l)
    mu = np.zeros(x_len)

    for i in range(x_len):
        window = x[i:i+l]
        mu[i] = np.ma.average(window)
    return mu

# %%
df = pd.read_csv('SPY-daily-2022-2023.csv', header=0, usecols=['Close'])
df
# Out:
#           Close
# 0    426.170013
# 1    435.619995
# 2    441.070007
# 3    444.519989
# 4    444.390015
# ..          ...
# 247  391.559998
# 248  385.910004
# 249  385.359985
# 250  391.730011
# 251  388.820007
#
# [252 rows x 1 columns]

# %%
#x = np.random.rand(100)

mu = SMA(df, 10)


plt.plot(df)
plt.plot(mu)
plt.show()
